# %%
import pandas as pd
from flask import Flask, render_template
import pymongo

# %%
file = "CleanedRDU.csv"
file2 = "airports.csv"

# %%
df = pd.read_csv(file)
dfmorgan = pd.read_csv(file2)

# %%
df.head()
# Out:
#   IATA                              AIRPORT           CITY STATE COUNTRY  \
# 0  ABQ            Albuquerque International    Albuquerque    NM     USA
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK     USA
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA     USA
# 3  AUS       Austin-Bergstrom International         Austin    TX     USA
# 4  BDL                Bradley International  Windsor Locks    CT     USA
#
#     LATITUDE   LONGITUDE
# 0  35.040222 -106.609194
# 1  61.174320 -149.996186
# 2  33.640444  -84.426944
# 3  30.194533  -97.669872
# 4  41.938874  -72.683228

# %%
origin_df = df.loc[df["Origin"] == "RDU"]

# %%
origin_df.head()
# Out:
#   Origin  OriginWac Dest  DestWac  Miles  NumTicketsOrdered AirlineCompany  \
# 0    RDU         36  PHL       23  337.0                1.0             AA
# 1    RDU         36  PHL       23  337.0                3.0             AA
# 2    RDU         36  PHL       23  337.0                2.0             AA
# 3    RDU         36  PHL       23  337.0                2.0             AA
# 4    RDU         36  PHL       23  337.0               11.0             AA
#
#    PricePerTicket
# 0          312.57
# 1          104.00
# 2          105.00
# 3          106.00
# 4          107.50

# %%
origin_df.count()
# Out:
# Origin               9370
# OriginWac            9370
# Dest                 9370
# DestWac              9370
# Miles                9370
# NumTicketsOrdered    9370
# AirlineCompany       9370
# PricePerTicket       9370
# dtype: int64

# %%
RDU_df = origin_df[["Origin", "OriginWac", "Dest",
                            "DestWac", "Miles", "NumTicketsOrdered", "AirlineCompany", "PricePerTicket"]]

# %%
RDU_df.head()
# Out:
#   Origin  OriginWac Dest  DestWac  Miles  NumTicketsOrdered AirlineCompany  \
# 0    RDU         36  PHL       23  337.0                1.0             AA
# 1    RDU         36  PHL       23  337.0                3.0             AA
# 2    RDU         36  PHL       23  337.0                2.0             AA
# 3    RDU         36  PHL       23  337.0                2.0             AA
# 4    RDU         36  PHL       23  337.0               11.0             AA
#
#    PricePerTicket
# 0          312.57
# 1          104.00
# 2          105.00
# 3          106.00
# 4          107.50

# %%
RDU_df.to_csv("CleanedRDU.csv",index=False)

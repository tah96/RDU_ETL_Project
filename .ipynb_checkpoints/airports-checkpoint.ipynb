# %%
import pandas as pd

# %%
file = "Cleaned_2018_RDU.csv"

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Unnamed: 0        ItinID         MktID  MktCoupons  Quarter Origin  \
# 0           0  2.018177e+10  2.018180e+12           1        1    PHL
# 1           1  2.018177e+10  2.018180e+12           1        1    PHL
# 2           2  2.018177e+10  2.018180e+12           1        1    PHL
# 3           3  2.018177e+10  2.018180e+12           1        1    PHL
# 4           4  2.018177e+10  2.018180e+12           1        1    PHL
#
#    OriginWac Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0         23  LAX       91  2402.0              2                1.0
# 1         23  LAX       91  2402.0              2                1.0
# 2         23  LAX       91  2402.0              2                1.0
# 3         23  LAX       91  2402.0              2                1.0
# 4         23  LAX       91  2402.0              2                1.0
#
#   AirlineCompany  PricePerTicket
# 0             AA          672.87
# 1             AA          367.68
# ...

# %%
origin_df = df.loc[df["Origin"] == "RDU"]

# %%
origin_df.head()
# Out:
#       Unnamed: 0        ItinID         MktID  MktCoupons  Quarter Origin  \
# 7445        7445  2.018178e+10  2.018180e+12           1        1    RDU
# 9086        9086  2.018178e+10  2.018180e+12           1        1    RDU
# 9089        9089  2.018178e+10  2.018180e+12           1        1    RDU
# 9091        9091  2.018178e+10  2.018180e+12           1        1    RDU
# 9093        9093  2.018178e+10  2.018180e+12           1        1    RDU
#
#       OriginWac Dest  DestWac  Miles  ContiguousUSA  NumTicketsOrdered  \
# 7445         36  PHL       23  337.0              2                1.0
# 9086         36  PHL       23  337.0              2                3.0
# 9089         36  PHL       23  337.0              2                2.0
# 9091         36  PHL       23  337.0              2                2.0
# 9093         36  PHL       23  337.0              2               11.0
#
#      AirlineCompany  PricePerTicket
# 7445             AA          312.57
# ...

# %%
origin_df.count()
# Out:
# Unnamed: 0           9370
# ItinID               9370
# MktID                9370
# MktCoupons           9370
# Quarter              9370
# Origin               9370
# OriginWac            9370
# Dest                 9370
# DestWac              9370
# Miles                9370
# ContiguousUSA        9370
# NumTicketsOrdered    9370
# AirlineCompany       9370
# PricePerTicket       9370
# dtype: int64

# %%
RDU_df = origin_df[["Origin", "OriginWac", "Dest",
                            "DestWac", "Miles", "NumTicketsOrdered", "AirlineCompany", "PricePerTicket"]]

# %%
RDU_df.head()
# Out:
#      Origin  OriginWac Dest  DestWac  Miles  NumTicketsOrdered AirlineCompany  \
# 7445    RDU         36  PHL       23  337.0                1.0             AA
# 9086    RDU         36  PHL       23  337.0                3.0             AA
# 9089    RDU         36  PHL       23  337.0                2.0             AA
# 9091    RDU         36  PHL       23  337.0                2.0             AA
# 9093    RDU         36  PHL       23  337.0               11.0             AA
#
#       PricePerTicket
# 7445          312.57
# 9086          104.00
# 9089          105.00
# 9091          106.00
# 9093          107.50

# %%
RDU_df.to_csv("CleanedRDU.csv",index=False)
